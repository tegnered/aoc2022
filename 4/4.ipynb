# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0,'../code')
import utils as ut
fn = 'input.txt'

# %% [markdown]
# ## 1

# %%
inp = ut.rl(fn)

# %%
inp
# Out:
# ['67-84,66-87',
#  '70-70,40-69',
#  '32-77,31-78',
#  '10-84,11-96',
#  '15-95,14-94',
#  '53-55,48-54',
#  '40-92,39-93',
#  '67-91,66-66',
#  '74-99,74-98',
#  '2-49,50-86',
#  '3-95,32-94',
#  '22-68,7-23',
#  '28-28,27-58',
#  '35-71,70-71',
#  '12-13,13-61',
#  '78-78,53-78',
#  '98-99,69-89',
#  '3-94,3-94',
#  '13-27,12-13',
#  '49-97,50-90',
#  '35-61,36-62',
#  '14-14,15-96',
#  '46-84,84-84',
#  '53-77,13-50',
#  '55-93,55-92',
#  '71-71,40-72',
#  '95-97,3-96',
#  '7-98,8-98',
#  '17-98,16-97',
#  '47-62,46-62',
#  '58-98,57-59',
#  '19-74,18-75',
#  '85-86,84-88',
#  '10-98,10-98',
#  '4-83,84-84',
#  '47-85,46-84',
#  '91-95,5-91',
#  '9-42,9-41',
#  '1-94,93-95',
#  '31-90,90-91',
#  '1-94,94-96',
#  '36-70,35-71',
#  '72-79,72-79',
#  '42-42,42-89',
#  '7-81,6-81',
#  '5-7,4-8',
#  '7-97,7-98',
#  '22-81,80-82',
#  '3-91,90-90',
#  '1-98,2-97',
#  '54-54,55-78',
#  '31-44,31-51',
#  '26-63,25-43',
#  '34-96,34-95',
#  '43-64,28-71',
#  '84-86,8-85',
#  '10-11,11-84',
# ...

# %%
sumpairs = 0
for pair in inp:
    elfs = pair.split(',')
    elfs = [elf.split('-') for elf in elfs]
    l1 = list(range(int(elfs[0][0]),int(elfs[0][1])+1))
    l2 = list(range(int(elfs[1][0]),int(elfs[1][1])+1))
    sumpairs += all([l in l2 for l in l1]) or all([l in l1 for l in l2])

# %%
sumpairs
# Out:
# 582

# %% [markdown]
# ## 2

# %%
sumpairs = 0
for pair in inp:
    elfs = pair.split(',')
    elfs = [elf.split('-') for elf in elfs]
    l1 = list(range(int(elfs[0][0]),int(elfs[0][1])+1))
    l2 = list(range(int(elfs[1][0]),int(elfs[1][1])+1))
    sumpairs += any([l in l2 for l in l1]) or any([l in l1 for l in l2])

# %%
sumpairs
# Out:
# 893
